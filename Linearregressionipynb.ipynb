# %% [markdown]
# <a href="https://colab.research.google.com/github/PUNNANAVYA/5C7/blob/main/Linearregressionipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from  sklearn.linear_model import LinearRegression

# %%
x= np.array([[1],[2],[3],[4],[5]])
y= np.array([1,2,2.5,4,4])

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
plt.scatter(x,y, color='blue')  # Actual data points
plt.plot(x, y_pred, color='red')  # Regression line
plt.title("Linear Regression")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): 0.2999999999999998
# Coefficient (β1): [0.8]

# %%
x = np.random.rand(100, 1) * 100  # 100 random numbers between 0 and 100
y = 2 * x + np.random.randn(100, 1) * 10  # Linear relation with some noise

# %%
plt.scatter(x, y, color='blue')
plt.title("Generated Dataset of 100 Numbers")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
plt.scatter(x,y, color='blue')  # Actual data points
plt.plot(x,y_pred, color='red')  # Regression line
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): [4.82043409]
# Coefficient (β1): [[1.91427583]]

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
df=pd.read_csv("/content/drive/MyDrive/diabetes.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
x=np.array([[72],[66],[64],[66],[40],[76],[70],[72],[60],[70]])
y=np.array([6,1,8,1,0,10,2,5,1,1])

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
plt.scatter(x,y, color='blue')  # Actual data points
plt.plot(x, y_pred, color='red')  # Regression line
plt.title("Linear Regression")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
